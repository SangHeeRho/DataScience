# %% [markdown]
# <a href="https://colab.research.google.com/github/SangHeeRho/DataScience/blob/main/unit12_%EC%A7%80%ED%95%98%EC%B2%A0_%EC%8B%9C%EA%B0%84%EB%8C%80%EB%B3%84_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%8B%9C%EA%B0%81%ED%99%94%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 지하철 시간대별 이용 현황 데이터 정제하기

# %%
import csv
f=open('subwaytime.csv')

data=csv.reader(f)

for row in data:
  print(row)

# %% [markdown]
# 헤더 제외하고 map 함수를 활용한 데이터 타입 바꾸기(문자열 -> 정수)

# %%
import csv
f=open('subwaytime.csv')

data=csv.reader(f)
next(data)
next(data)

for row in data :
  row[4:] = map(int, row[4:])
  print(row)

# %% [markdown]
# 출근 시간대 사람들이 가장 많이 타고 내리는 역은 어디일까

# %% [markdown]
# 아침 7시 승차 데이터 추출 -> 10번 인덱스 데이터 값 추출

# %%
import csv
f=open('subwaytime.csv')

data=csv.reader(f)
next(data)
next(data)

result =[] #아침 7시 승차 데이터 추출 -> 10번째 인덱스에 존재

for row in data :
  row[4:] = map(int, row[4:])
  result.append(row[10])

print(len(result))
print(result)
# Out:
# 598
# ...

# %%
import csv
import matplotlib.pyplot as plt

f=open('subwaytime.csv')

data=csv.reader(f)
next(data)
next(data)

result =[] #아침 7시 승차 데이터 추출 -> 10번째 인덱스에 존재

for row in data :
  row[4:] = map(int, row[4:])
  result.append(row[10])

# 데이터 시각화
plt.figure(dpi=200)
plt.style.use('ggplot')
plt.bar(range(len(result)),result)
plt.show()

# %% [markdown]
# 오름차순으로 데이터 정렬하여 그래프 그리기

# %%
import csv
import matplotlib.pyplot as plt

f=open('subwaytime.csv')

data=csv.reader(f)
next(data)
next(data)

result =[] #아침 7시 승차 데이터 추출 -> 10번째 인덱스에 존재

for row in data :
  row[4:] = map(int, row[4:])
  result.append(row[10])

result.sort()
# 데이터 시각화
plt.figure(dpi=200)
plt.style.use('ggplot')
plt.bar(range(len(result)),result)
plt.show()

# %% [markdown]
# 출근 시간 (7-9시) 막대 그래프 그리기

# %%
import csv
import matplotlib.pyplot as plt

f=open('subwaytime.csv')

data=csv.reader(f)
next(data)
next(data)

result =[] #출근시간 (7시-9시) 승차 데이터 추출 -> 10,12,14 인덱스에 존재

for row in data :
  row[4:] = map(int, row[4:])
  result.append(sum(row[10:15:2])) # 10, 12, 14 추출

result.sort() # 데이터를 오름차순으로 정렬
# 데이터 시각화
plt.figure(dpi=200)
plt.style.use('ggplot')
plt.bar(range(len(result)),result)
plt.show()

# %% [markdown]
# 7시부터 9시까지 승차 인원 합계의 최댓값 찾기

# %%
import csv
import matplotlib.pyplot as plt

f=open('subwaytime.csv')

data=csv.reader(f)
next(data)
next(data)

mx = 0
mx_station =''

result =[] #출근시간 (7시-9시) 승차 데이터 추출 -> 10,12,14 인덱스에 존재

for row in data :
  row[4:] = map(int, row[4:])
  if sum(row[10:14:2]) > mx :
    mx = sum(row[10:14:2])
    mx_station = row[3] + '(' + row[1] + ')'

print(mx_station, mx)
# Out:
# 신림(2호선) 809541

# %% [markdown]
# 출근 시간대에 사람들이 가장 많이 내리는 역 찾기

# %%
import csv
import matplotlib.pyplot as plt

f=open('subwaytime.csv')

data=csv.reader(f)
next(data)
next(data)

mx = 0
mx_station =''

result =[] #출근시간 (7시-9시) 승차 데이터 추출 -> 10,12,14 인덱스에 존재

for row in data :
  row[4:] = map(int, row[4:])
  if sum(row[11:15:2]) > mx :
    mx = sum(row[11:15:2])
    mx_station = row[3] + '(' + row[1] + ')'

print(mx_station, mx)
# Out:
# 강남(2호선) 563549

# %% [markdown]
# 퇴근시간대 사람들이 가장 많이 타고 내리는 역은 어디일까<br>
# 저녁 6~8시 승차, 하차 인원 최대 역 찾기<br>
# 1) 막대그래프로 퇴근 시간대 표출<br>
# 2) 최대 승차 역<br>
# 3) 최대 하차 역

# %%
import csv
import matplotlib.pyplot as plt

f=open('subwaytime.csv')

data=csv.reader(f)
next(data)
next(data)

mx_off_in = 0
mx_off_in_station =''

result =[] #퇴근시간 (오후 6시-8시) 승차 데이터 추출 -> 32, 34 인덱스에 존재

for row in data :
  row[4:] = map(int, row[4:])
  if sum(row[32:36:2]) > mx_off_in :
    mx_off_in = sum(row[32:36:2])
    mx_off_in_station = row[3] + '(' + row[1] + ')'

import csv
import matplotlib.pyplot as plt

f=open('subwaytime.csv')

data=csv.reader(f)
next(data)
next(data)

mx_off_off = 0
mx_off_off_station =''

result =[] #퇴근시간 (오후 6시-8시) 하차 데이터 추출 -> 33, 35 인덱스에 존재

for row in data :
  row[4:] = map(int, row[4:])
  if sum(row[33:37:2]) > mx_off_off :
    mx_off_off = sum(row[33:37:2])
    mx_off_off_station = row[3] + '(' + row[1] + ')'


print(mx_off_in_station, mx_off_in)
print(mx_off_off_station, mx_off_off)

result1 =[]
for row in data :
  row[4:] = map(int, row[4:])
  result1.append(sum(row[32:36:2]))

result2 =[]
for row in data :
  row[4:] = map(int, row[4:])
  result2.append(sum(row[33:37:2]))

result1.sort() # 데이터를 오름차순으로 정렬
# 데이터 시각화
plt.figure(dpi=200)
plt.style.use('ggplot')
plt.bar(range(len(result1)),result1)
plt.show()

result2.sort() # 데이터를 오름차순으로 정렬
# 데이터 시각화
plt.figure(dpi=200)
plt.style.use('ggplot')
plt.bar(range(len(result2)),result2)
plt.show()
# Out:
# 강남(2호선) 723636
# 신림(2호선) 561336

# %%
import csv
import matplotlib.pyplot as plt

f=open('subwaytime.csv')

data=csv.reader(f)
next(data)
next(data)

mx_off_in = 0
mx_off_in_station =''

result =[] #퇴근시간 (오후 7시-9시) 승차 데이터 추출 -> 34, 36, 38 인덱스에 존재

for row in data :
  row[4:] = map(int, row[4:])
  if sum(row[34:38:2]) > mx_off_in :
    mx_off_in = sum(row[34:38:2])
    mx_off_in_station = row[3] + '(' + row[1] + ')'

print(mx_off_in_station, mx_off_in)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-9765ad116ece> in <module>()
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 f=open('subwaytime.csv')
#       5
#       6 data=csv.reader(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'subwaytime.csv'

# %% [markdown]
# 밤 11시에 사람들이 가장 많이 타는 역은 어디일까

# %% [markdown]
# 승차 패턴 찾기<br>
# 승차 시각이 1시간씩 늦어질 때 마다 인덱스 2씩 늘어남 <br> 승차 시작 시간의 인덱스 값 4 -> 4시부터 승차가 시작(첫차)<br>
# 승차 시각(t) 와 승차 인원이 적힌 인덱스(i) 관계 분석 <br>
# i = 4 + (t -4) * 2

# %%
import csv
import matplotlib.pyplot as plt

f=open('subwaytime.csv')

data=csv.reader(f)
next(data)
next(data)

mx=0
mx_station=''

t = int(input('몇 시의 승차인원이 가장 많은 역이 궁금하세요? : '))
for row in data :
  row[4:] = map(int, row[4:])
  a = row[4 + (t-4)*2] # 입력 받은 시각의 승차 인원 값 추출

  if a > mx :
    mx = a
    mx_station = row[3] + '(' + row[1] + ')'

print(mx_station, mx)
# Out:
# 몇 시의 승차인원이 가장 많은 역이 궁금하세요? : 5
# 홍대입구(2호선) 42966

# %% [markdown]
# 한글 깨짐 방지

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %% [markdown]
# 시간대별 최대 승차 역 이름 및 승차 인원 막대 그래프로 표현하기

# %%
import csv
import matplotlib.pyplot as plt

f=open('subwaytime.csv')

data=csv.reader(f)
next(data)
next(data)

mx=[0] * 24
mx_station =[''] * 24

for row in data:
  row[4: ] = map(int, row[4:])
  for j in range(24) :
    a = row[j * 2 + 4] # 시간대별 패턴 i = j * 2 + 4 (j는 0 ~ 23까지 -> 시작 인덱스 4)
    if a > mx[j] :
      mx[j] = a
      mx_station[j] = row[3] + '(' + str(j+4)+')'

plt.rc('font', family = 'NanumBarunGothic')
plt.style.use('ggplot')
plt.figure(dpi=200)
plt.bar(range(24), mx)
plt.xticks(range(24), mx_station, rotation=90) # x축 90도 돌림
plt.show()

# %% [markdown]
# 시간대별로 하차 인원이 가장 많은 역 막대 그래프로 표현하기

# %%
import csv
import matplotlib.pyplot as plt

f=open('subwaytime.csv')

data=csv.reader(f)
next(data)
next(data)

mx=[0] * 24
mx_station =[''] * 24

for row in data:
  row[4: ] = map(int, row[4:])
  for j in range(24) :
    a = row[5 + j * 2] # 시간대별 패턴 i = 5 + j * 2 (j는 0 ~ 23까지 -> 시작 인덱스 4)
    if a > mx[j] :
      mx[j] = a
      mx_station[j] = row[3] + '(' + str(j+5)+')'

plt.rc('font', family = 'NanumBarunGothic')
plt.style.use('ggplot')
plt.figure(dpi=200)
plt.bar(range(24), mx)
plt.xticks(range(24), mx_station, rotation=90) # x축 90도 돌림
plt.show()

# %% [markdown]
# 모든 지하철역에서 시간대별 승하차 인원을 모두 더하면

# %%
import csv
import matplotlib.pyplot as plt

f=open('subwaytime.csv')

data=csv.reader(f)
next(data)
next(data)

s_in = [0] * 24
s_out = [0] * 24

for row in data :
  row[4: ] = map(int,row[4:])
  for i in range(24) :
    s_in[i] += row[4 + i * 2] #승차
    s_out[i] += row[5 + i * 2] #하차

plt.rc('font', family = 'NanumBarunGothic')
plt.style.use('ggplot')
plt.figure(dpi=200)
plt.title('지하철 시간대별 승하차 인원 추이')
plt.plot(s_in, label='승차')
plt.plot(s_out, label='하차')
plt.legend()
plt.xticks(range(24),range(4,28))
plt.show()
